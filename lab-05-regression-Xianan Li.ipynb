# %% [markdown]
# ## Toluca Dataset

# %%
# Instruction:
# For each predictor, your implementation must:
#     - Plot the predictor against the target
#     - Plot the residual against the target
#     - Determine the coefficients (slope, intercept) against the target

# %%
import pandas as pd

df = pd.read_csv('toluca.csv')
df
# Out:
#     lotSize  workHours
# 0        80        399
# 1        30        121
# 2        50        221
# 3        90        376
# 4        70        361
# 5        60        224
# 6       120        546
# 7        80        352
# 8       100        353
# 9        50        157
# 10       40        160
# 11       70        252
# 12       90        389
# 13       20        113
# 14      110        435
# 15      100        420
# 16       30        212
# 17       50        268
# 18       90        377
# 19      110        421
# 20       30        273
# 21       90        468
# 22       40        244
# 23       80        342
# 24       70        323

# %%
#     - Plot the predictor against the target

import matplotlib.pyplot as plt
# %matplotlib inline

df.plot(kind='scatter', x='lotSize', y='workHours')

# %%
import seaborn as sns
plot = sns.lmplot(y='workHours', x='lotSize', data=df)

# %%
#     - Plot the residual against the target

r1 = sns.residplot('lotSize', 'workHours', data=df)
r1.set(xlabel='Lot Size', ylabel='Residuals')
r1

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df.drop('workHours', axis=1), df.iloc[:,1])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#     - Determine the coefficients (slope, intercept) against the target
print("slop: ", lin_reg.coef_)
print("intercept: ", lin_reg.intercept_)
# Out:
# slop:  [3.57020202]
# intercept:  62.36585858585849

# %% [markdown]
# ## Credit Dataset

# %%
df_credit = pd.read_csv('Credit.csv')
df_credit
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %%
#     - Plot the predictor against the target
#     - Predictor: Income Target: Limit
df_credit.plot(kind='scatter', x='Income', y='Limit')

# %%
#     - Predictor: Rating Target: Limit
df_credit.plot(kind='scatter', x='Rating', y='Limit')

# %%
#     - Predictor: Cards Target: Limit
df_credit.plot(kind='scatter', x='Cards', y='Limit')

# %%
#     - Predictor: Age Target: Limit
df_credit.plot(kind='scatter', x='Age', y='Limit')

# %%
#     - Predictor: Education Target: Limit
df_credit.plot(kind='scatter', x='Education', y='Limit')

# %%
#     - Plot the residual against the target
#     - Predictor: Income Target: Limit
sns.residplot('Income', 'Limit', data=df_credit)

# %%
#     - Predictor: Rating Target: Limit
sns.residplot('Rating', 'Limit', data=df_credit)

# %%
#     - Predictor: Income Target: Limit
sns.residplot('Cards', 'Limit', data=df_credit)

# %%
#     - Predictor: Age Target: Limit
sns.residplot('Age', 'Limit', data=df_credit)

# %%
#     - Predictor: Education Target: Limit
sns.residplot('Education', 'Limit', data=df_credit)

# %%
#     - Determine the coefficients (slope, intercept) against the target

lin_reg = LinearRegression()
lin_reg.fit(df_credit[['Income']], df_credit['Limit'])
print("coefficient = ", lin_reg.coef_, 
      " intercept = ", lin_reg.intercept_)
# Out:
# coefficient =  [51.8750206]  intercept =  2389.8694089155265

# %% [raw]
# Income is not suitable for SLR

# %%
lin_reg = LinearRegression()
lin_reg.fit(df_credit[['Rating']], df_credit['Limit'])
print("coefficient = ", lin_reg.coef_, 
      " intercept = ", lin_reg.intercept_)
# Out:
# coefficient =  [14.87160712]  intercept =  -542.928229986901

# %% [raw]
# Rating is suitable for SLR

# %%
lin_reg = LinearRegression()
lin_reg.fit(df_credit[['Cards']], df_credit['Limit'])
print("coefficient = ", lin_reg.coef_, 
      " intercept = ", lin_reg.intercept_)
# Out:
# coefficient =  [17.22189457]  intercept =  4684.666246822009

# %% [raw]
# Cards is not suitable for SLR

# %%
lin_reg = LinearRegression()
lin_reg.fit(df_credit[['Age']], df_credit['Limit'])
print("coefficient = ", lin_reg.coef_, 
      " intercept = ", lin_reg.intercept_)
# Out:
# coefficient =  [13.49982568]  intercept =  3984.0984540274258

# %% [raw]
# Age is not suitable for SLR

# %%
lin_reg = LinearRegression()
lin_reg.fit(df_credit[['Education']], df_credit['Limit'])
print("coefficient = ", lin_reg.coef_, 
      " intercept = ", lin_reg.intercept_)
# Out:
# coefficient =  [-17.39235309]  intercept =  4969.527149089043

# %% [raw]
# Education is not issuitable for SLR
